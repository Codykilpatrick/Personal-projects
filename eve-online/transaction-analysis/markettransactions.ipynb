# %%
import pandas as pd

# %%
df = pd.read_csv('market-transactions-07nov.csv')

# %%
df = df.drop('client', axis=1)

# %%
df
# Out:
#                  date quantity             type unit_price        total  \
# 0    2022.11.09 16:53        1          Gamma S  3,128 ISK   -3,128 ISK
# 1    2022.11.09 16:52        1          Gamma S  3,128 ISK   -3,128 ISK
# 2    2022.11.09 16:14        1          Gamma S  3,128 ISK   -3,128 ISK
# 3    2022.11.09 15:53        1          Gamma S  3,128 ISK   -3,128 ISK
# 4    2022.11.09 15:19       30            Crash      8 ISK     -243 ISK
# ..                ...      ...              ...        ...          ...
# 597  2022.11.07 16:50      173  Electronic Link    101 ISK  -17,507 ISK
# 598  2022.11.07 16:49       22  Electronic Link    101 ISK   -2,226 ISK
# 599  2022.11.07 16:49       32  Electronic Link    101 ISK   -3,238 ISK
# 600  2022.11.07 16:49      520  Electronic Link    101 ISK  -52,624 ISK
# 601  2022.11.07 16:49       15  Electronic Link    101 ISK   -1,518 ISK
#
#                                               where
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['unit_price'] = df['unit_price'].str.replace('ISK', '')

# %%
df['unit_price'] = df['unit_price'].str.replace(',', '')

# %%
df['total'] = df['total'].str.replace('ISK', '')

# %%
df['total'] = df['total'].str.replace(',', '')

# %%
df['quantity'] = df['quantity'].str.replace(',', '')

# %%
df
# Out:
#                    date quantity             type unit_price    total  \
# 0   2022-11-09 16:53:00        1          Gamma S      3128    -3128
# 1   2022-11-09 16:52:00        1          Gamma S      3128    -3128
# 2   2022-11-09 16:14:00        1          Gamma S      3128    -3128
# 3   2022-11-09 15:53:00        1          Gamma S      3128    -3128
# 4   2022-11-09 15:19:00       30            Crash         8     -243
# ..                  ...      ...              ...        ...      ...
# 597 2022-11-07 16:50:00      173  Electronic Link       101   -17507
# 598 2022-11-07 16:49:00       22  Electronic Link       101    -2226
# 599 2022-11-07 16:49:00       32  Electronic Link       101    -3238
# 600 2022-11-07 16:49:00      520  Electronic Link       101   -52624
# 601 2022-11-07 16:49:00       15  Electronic Link       101    -1518
#
#                                               where
# 0    Jita IV - Moon 4 - Caldari Navy Assembly Plant
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 602 entries, 0 to 601
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        602 non-null    datetime64[ns]
#  1   quantity    602 non-null    object
#  2   type        602 non-null    object
#  3   unit_price  602 non-null    object
#  4   total       602 non-null    object
#  5   where       602 non-null    object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 28.3+ KB

# %%
df['unit_price'] = df['unit_price'].astype(str).astype(int)

# %%
df['total'] = df['total'].astype(str).astype(int)

# %%
df['quantity'] = df['quantity'].astype(str).astype(int)

# %%
df
# Out:
#                    date  quantity             type  unit_price  total  \
# 0   2022-11-09 16:53:00         1          Gamma S        3128  -3128
# 1   2022-11-09 16:52:00         1          Gamma S        3128  -3128
# 2   2022-11-09 16:14:00         1          Gamma S        3128  -3128
# 3   2022-11-09 15:53:00         1          Gamma S        3128  -3128
# 4   2022-11-09 15:19:00        30            Crash           8   -243
# ..                  ...       ...              ...         ...    ...
# 597 2022-11-07 16:50:00       173  Electronic Link         101 -17507
# 598 2022-11-07 16:49:00        22  Electronic Link         101  -2226
# 599 2022-11-07 16:49:00        32  Electronic Link         101  -3238
# 600 2022-11-07 16:49:00       520  Electronic Link         101 -52624
# 601 2022-11-07 16:49:00        15  Electronic Link         101  -1518
#
#                                               where
# 0    Jita IV - Moon 4 - Caldari Navy Assembly Plant
# ...

# %%
total_sum = df.total.sum()

# %%
total_sum
# Out:
# -83897756

# %%
#-83,897,756

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 602 entries, 0 to 601
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        602 non-null    datetime64[ns]
#  1   quantity    602 non-null    int32
#  2   type        602 non-null    object
#  3   unit_price  602 non-null    int32
#  4   total       602 non-null    int32
#  5   where       602 non-null    object
# dtypes: datetime64[ns](1), int32(3), object(2)
# memory usage: 21.3+ KB

# %%
#standards = df[df['type']=='Standard S']

# %%
#standards

# %%
df_combined = df_combined.drop('unit_price', axis=1)

# %%
df_combined.sort_values('total', ascending=False)
# Out:
#                                                quantity     total
# type
# Crash                                               240     -1932
# Talocan Intricate Formulas                           25    -25225
# Talocan Automation Accounts                          22    -66290
# Shadow Iron Charge S                               6895   -103493
# Spare Parts                                        1803   -128247
# Deluge Enduring Burst Jammer                         27   -148656
# Talocan Reflective Sheets                            20   -155256
# Advanced 'Limos' Heavy Missile Bay I                 25   -213625
# Electronic Link                                    2990   -302581
# Takmahl Cohere Cord                                  32   -323990
# Enormous Freight Container                            1   -396000
# F-90 Compact Sensor Booster                         162   -517856
# Variegated Asteroid Mining Crystal Type A II         14   -822080
# ...
